# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import warnings
import time

warnings.simplefilter(action = 'ignore', category = FutureWarning)

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36'
}

def scrape_data_for_year(code, league, year):
    url = f'https://www.transfermarkt.co.uk/{league}/startseite/wettbewerb/{code}/plus/?saison_id={year}'

    for attempt in range(10):
        wait_time = 2
        try:
            response = requests.get(url, headers = headers)

            if response.status_code == 200:
                break

            else:
                if attempt < 5:
                    print(f'Status {response.status_code} for {league} in {year} - Attempt {attempt + 1} - Error code {response.status_code}')
                    time.sleep(wait_time ** (attempt + 1))
                else:
                    print(f'Failed to retrieve data for {league} in {year}')
                    return None, None
                
        except requests.exceptions.RequestException as e:
            if attempt < 5:
                print(f'Request error for {league} in {year} - Attempt {attempt + 1} - Error code {e}')
                time.sleep(wait_time ** (attempt + 1))
            else:
                print(f'Request error for {league} in {year} after 5 retries: {e}')
                return None, None

    

    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find_all('table', class_='items')[0]
    tbody = table.find('tbody')

    team_links = []

    season = soup.find_all('h2', class_ = 'content-box-headline')[1].text.strip()

    if tbody:
        for row in tbody.find_all('tr'):
            team_link = row.find('a', href = True)
            if team_link:
                href = team_link['href']
                team_links.append(href)

    print(f'\n{league} and {year} - Successfully scraped\n')
    return season, team_links

# %%
leagues = [('premier-league', 'GB1'), ('laliga', 'ES1'), ('serie-a', 'IT1'), ('bundesliga', 'L1'), ('ligue-1', 'FR1'),
           ('championship', 'GB2'), ('laliga2', 'ES2'), ('serie-b', 'IT2'), ('2-bundesliga', 'L2'), ('ligue-2', 'FR2')]

for league, code in leagues:
    data = []
    for year in range(2011, 2025):
        print(f'Scraping data for {league} in {year}...')
        season, team_links = scrape_data_for_year(code, league, year)

        if season and team_links:
            for link in team_links:
                data.append({
                    'Season':season,
                    'Team Link': link
                })
    
    df = pd.DataFrame(data)
    df.to_csv(f'test/{league}_team_links.csv', index = False)
    print(f'Team links for {league} saved.')
# Out:
# Scraping data for premier-league in 2011...
#
# premier-league and 2011 - Successfully scraped
#
# Scraping data for premier-league in 2012...
#
# premier-league and 2012 - Successfully scraped
#
# Scraping data for premier-league in 2013...
#
# premier-league and 2013 - Successfully scraped
#
# Scraping data for premier-league in 2014...
#
# premier-league and 2014 - Successfully scraped
#
# Scraping data for premier-league in 2015...
#
# premier-league and 2015 - Successfully scraped
#
# Scraping data for premier-league in 2016...
#
# premier-league and 2016 - Successfully scraped
#
# Scraping data for premier-league in 2017...
#
# premier-league and 2017 - Successfully scraped
#
# Scraping data for premier-league in 2018...
#
# premier-league and 2018 - Successfully scraped
#
# Scraping data for premier-league in 2019...
#
# premier-league and 2019 - Successfully scraped
#
# Scraping data for premier-league in 2020...
#
# premier-league and 2020 - Successfully scraped
#
# Scraping data for premier-league in 2021...
# Status 403 for premier-league in 2021 - Attempt 1 - Error code 403
# Status 403 for premier-league in 2021 - Attempt 2 - Error code 403
# Status 403 for premier-league in 2021 - Attempt 3 - Error code 403
# Status 403 for premier-league in 2021 - Attempt 4 - Error code 403
#
# premier-league and 2021 - Successfully scraped
#
# Scraping data for premier-league in 2022...
#
# premier-league and 2022 - Successfully scraped
#
# Scraping data for premier-league in 2023...
#
# premier-league and 2023 - Successfully scraped
#
# Scraping data for premier-league in 2024...
#
# premier-league and 2024 - Successfully scraped
#
# Team links for premier-league saved.
# Scraping data for laliga in 2011...
#
# laliga and 2011 - Successfully scraped
#
# Scraping data for laliga in 2012...
#
# laliga and 2012 - Successfully scraped
#
# Scraping data for laliga in 2013...
#
# laliga and 2013 - Successfully scraped
#
# Scraping data for laliga in 2014...
# Status 403 for laliga in 2014 - Attempt 1 - Error code 403
# Status 403 for laliga in 2014 - Attempt 2 - Error code 403
#
# laliga and 2014 - Successfully scraped
#
# Scraping data for laliga in 2015...
# Status 403 for laliga in 2015 - Attempt 1 - Error code 403
# Status 403 for laliga in 2015 - Attempt 2 - Error code 403
#
# laliga and 2015 - Successfully scraped
#
# Scraping data for laliga in 2016...
#
# laliga and 2016 - Successfully scraped
#
# Scraping data for laliga in 2017...
#
# laliga and 2017 - Successfully scraped
#
# Scraping data for laliga in 2018...
#
# laliga and 2018 - Successfully scraped
#
# Scraping data for laliga in 2019...
# Status 403 for laliga in 2019 - Attempt 1 - Error code 403
#
# laliga and 2019 - Successfully scraped
#
# Scraping data for laliga in 2020...
# Status 403 for laliga in 2020 - Attempt 1 - Error code 403
# Status 403 for laliga in 2020 - Attempt 2 - Error code 403
# Status 403 for laliga in 2020 - Attempt 3 - Error code 403
# Status 403 for laliga in 2020 - Attempt 4 - Error code 403
#
# laliga and 2020 - Successfully scraped
#
# Scraping data for laliga in 2021...
#
# laliga and 2021 - Successfully scraped
#
# Scraping data for laliga in 2022...
#
# laliga and 2022 - Successfully scraped
#
# Scraping data for laliga in 2023...
#
# laliga and 2023 - Successfully scraped
#
# Scraping data for laliga in 2024...
#
# laliga and 2024 - Successfully scraped
#
# Team links for laliga saved.
# Scraping data for serie-a in 2011...
# Status 403 for serie-a in 2011 - Attempt 1 - Error code 403
# Status 403 for serie-a in 2011 - Attempt 2 - Error code 403
#
# serie-a and 2011 - Successfully scraped
#
# Scraping data for serie-a in 2012...
#
# serie-a and 2012 - Successfully scraped
#
# Scraping data for serie-a in 2013...
#
# serie-a and 2013 - Successfully scraped
#
# Scraping data for serie-a in 2014...
# Status 403 for serie-a in 2014 - Attempt 1 - Error code 403
# Status 403 for serie-a in 2014 - Attempt 2 - Error code 403
# Status 403 for serie-a in 2014 - Attempt 3 - Error code 403
# Status 403 for serie-a in 2014 - Attempt 4 - Error code 403
#
# serie-a and 2014 - Successfully scraped
#
# Scraping data for serie-a in 2015...
# Status 403 for serie-a in 2015 - Attempt 1 - Error code 403
# Status 403 for serie-a in 2015 - Attempt 2 - Error code 403
# Status 403 for serie-a in 2015 - Attempt 3 - Error code 403
# Status 403 for serie-a in 2015 - Attempt 4 - Error code 403
#
# serie-a and 2015 - Successfully scraped
#
# Scraping data for serie-a in 2016...
#
# serie-a and 2016 - Successfully scraped
#
# Scraping data for serie-a in 2017...
#
# serie-a and 2017 - Successfully scraped
#
# Scraping data for serie-a in 2018...
# Status 403 for serie-a in 2018 - Attempt 1 - Error code 403
#
# serie-a and 2018 - Successfully scraped
#
# Scraping data for serie-a in 2019...
# Status 403 for serie-a in 2019 - Attempt 1 - Error code 403
# Status 403 for serie-a in 2019 - Attempt 2 - Error code 403
#
# serie-a and 2019 - Successfully scraped
#
# Scraping data for serie-a in 2020...
#
# serie-a and 2020 - Successfully scraped
#
# Scraping data for serie-a in 2021...
#
# serie-a and 2021 - Successfully scraped
#
# Scraping data for serie-a in 2022...
# Status 403 for serie-a in 2022 - Attempt 1 - Error code 403
#
# serie-a and 2022 - Successfully scraped
#
# Scraping data for serie-a in 2023...
#
# serie-a and 2023 - Successfully scraped
#
# Scraping data for serie-a in 2024...
#
# serie-a and 2024 - Successfully scraped
#
# Team links for serie-a saved.
# Scraping data for bundesliga in 2011...
# Status 403 for bundesliga in 2011 - Attempt 1 - Error code 403
#
# bundesliga and 2011 - Successfully scraped
#
# Scraping data for bundesliga in 2012...
# Status 403 for bundesliga in 2012 - Attempt 1 - Error code 403
# Status 403 for bundesliga in 2012 - Attempt 2 - Error code 403
# Status 403 for bundesliga in 2012 - Attempt 3 - Error code 403
# Status 403 for bundesliga in 2012 - Attempt 4 - Error code 403
#
# bundesliga and 2012 - Successfully scraped
#
# Scraping data for bundesliga in 2013...
#
# bundesliga and 2013 - Successfully scraped
#
# Scraping data for bundesliga in 2014...
# Status 403 for bundesliga in 2014 - Attempt 1 - Error code 403
#
# bundesliga and 2014 - Successfully scraped
#
# Scraping data for bundesliga in 2015...
# Status 403 for bundesliga in 2015 - Attempt 1 - Error code 403
# Status 403 for bundesliga in 2015 - Attempt 2 - Error code 403
# Status 403 for bundesliga in 2015 - Attempt 3 - Error code 403
# Status 403 for bundesliga in 2015 - Attempt 4 - Error code 403
#
# bundesliga and 2015 - Successfully scraped
#
# Scraping data for bundesliga in 2016...
#
# bundesliga and 2016 - Successfully scraped
#
# Scraping data for bundesliga in 2017...
# Status 403 for bundesliga in 2017 - Attempt 1 - Error code 403
# Status 403 for bundesliga in 2017 - Attempt 2 - Error code 403
# Status 403 for bundesliga in 2017 - Attempt 3 - Error code 403
# Status 403 for bundesliga in 2017 - Attempt 4 - Error code 403
#
# bundesliga and 2017 - Successfully scraped
#
# Scraping data for bundesliga in 2018...
#
# bundesliga and 2018 - Successfully scraped
#
# Scraping data for bundesliga in 2019...
# Status 403 for bundesliga in 2019 - Attempt 1 - Error code 403
#
# bundesliga and 2019 - Successfully scraped
#
# Scraping data for bundesliga in 2020...
# Status 403 for bundesliga in 2020 - Attempt 1 - Error code 403
# Status 403 for bundesliga in 2020 - Attempt 2 - Error code 403
# Status 403 for bundesliga in 2020 - Attempt 3 - Error code 403
# Status 403 for bundesliga in 2020 - Attempt 4 - Error code 403
# Status 403 for bundesliga in 2020 - Attempt 5 - Error code 403
# Failed to retrieve data for bundesliga in 2020
# Scraping data for bundesliga in 2021...
# Status 403 for bundesliga in 2021 - Attempt 1 - Error code 403
#
# bundesliga and 2021 - Successfully scraped
#
# Scraping data for bundesliga in 2022...
#
# bundesliga and 2022 - Successfully scraped
#
# Scraping data for bundesliga in 2023...
#
# bundesliga and 2023 - Successfully scraped
#
# Scraping data for bundesliga in 2024...
# Status 403 for bundesliga in 2024 - Attempt 1 - Error code 403
# Status 403 for bundesliga in 2024 - Attempt 2 - Error code 403
#
# bundesliga and 2024 - Successfully scraped
#
# Team links for bundesliga saved.
# Scraping data for ligue-1 in 2011...
# Status 403 for ligue-1 in 2011 - Attempt 1 - Error code 403
#
# ligue-1 and 2011 - Successfully scraped
#
# Scraping data for ligue-1 in 2012...
# Status 403 for ligue-1 in 2012 - Attempt 1 - Error code 403
# Status 403 for ligue-1 in 2012 - Attempt 2 - Error code 403
#
# ligue-1 and 2012 - Successfully scraped
#
# Scraping data for ligue-1 in 2013...
#
# ligue-1 and 2013 - Successfully scraped
#
# Scraping data for ligue-1 in 2014...
#
# ligue-1 and 2014 - Successfully scraped
#
# Scraping data for ligue-1 in 2015...
# Status 403 for ligue-1 in 2015 - Attempt 1 - Error code 403
# Status 403 for ligue-1 in 2015 - Attempt 2 - Error code 403
#
# ligue-1 and 2015 - Successfully scraped
#
# Scraping data for ligue-1 in 2016...
# Status 403 for ligue-1 in 2016 - Attempt 1 - Error code 403
# Status 403 for ligue-1 in 2016 - Attempt 2 - Error code 403
#
# ligue-1 and 2016 - Successfully scraped
#
# Scraping data for ligue-1 in 2017...
# Status 403 for ligue-1 in 2017 - Attempt 1 - Error code 403
#
# ligue-1 and 2017 - Successfully scraped
#
# Scraping data for ligue-1 in 2018...
#
# ligue-1 and 2018 - Successfully scraped
#
# Scraping data for ligue-1 in 2019...
# Status 403 for ligue-1 in 2019 - Attempt 1 - Error code 403
# Status 403 for ligue-1 in 2019 - Attempt 2 - Error code 403
#
# ligue-1 and 2019 - Successfully scraped
#
# Scraping data for ligue-1 in 2020...
#
# ligue-1 and 2020 - Successfully scraped
#
# Scraping data for ligue-1 in 2021...
# Status 403 for ligue-1 in 2021 - Attempt 1 - Error code 403
#
# ligue-1 and 2021 - Successfully scraped
#
# Scraping data for ligue-1 in 2022...
#
# ligue-1 and 2022 - Successfully scraped
#
# Scraping data for ligue-1 in 2023...
# Status 403 for ligue-1 in 2023 - Attempt 1 - Error code 403
# Status 403 for ligue-1 in 2023 - Attempt 2 - Error code 403
#
# ligue-1 and 2023 - Successfully scraped
#
# Scraping data for ligue-1 in 2024...
# Status 403 for ligue-1 in 2024 - Attempt 1 - Error code 403
# Status 403 for ligue-1 in 2024 - Attempt 2 - Error code 403
# Status 403 for ligue-1 in 2024 - Attempt 3 - Error code 403
# Status 403 for ligue-1 in 2024 - Attempt 4 - Error code 403
# Status 403 for ligue-1 in 2024 - Attempt 5 - Error code 403
#
# ligue-1 and 2024 - Successfully scraped
#
# Team links for ligue-1 saved.
# Scraping data for championship in 2011...
#
# championship and 2011 - Successfully scraped
#
# Scraping data for championship in 2012...
#
# championship and 2012 - Successfully scraped
#
# Scraping data for championship in 2013...
#
# championship and 2013 - Successfully scraped
#
# Scraping data for championship in 2014...
#
# championship and 2014 - Successfully scraped
#
# Scraping data for championship in 2015...
#
# championship and 2015 - Successfully scraped
#
# Scraping data for championship in 2016...
#
# championship and 2016 - Successfully scraped
#
# Scraping data for championship in 2017...
#
# championship and 2017 - Successfully scraped
#
# Scraping data for championship in 2018...
#
# championship and 2018 - Successfully scraped
#
# Scraping data for championship in 2019...
#
# championship and 2019 - Successfully scraped
#
# Scraping data for championship in 2020...
# Status 403 for championship in 2020 - Attempt 1 - Error code 403
#
# championship and 2020 - Successfully scraped
#
# Scraping data for championship in 2021...
# Status 403 for championship in 2021 - Attempt 1 - Error code 403
# Status 403 for championship in 2021 - Attempt 2 - Error code 403
# Status 403 for championship in 2021 - Attempt 3 - Error code 403
#
# championship and 2021 - Successfully scraped
#
# Scraping data for championship in 2022...
#
# championship and 2022 - Successfully scraped
#
# Scraping data for championship in 2023...
# Status 403 for championship in 2023 - Attempt 1 - Error code 403
# Status 403 for championship in 2023 - Attempt 2 - Error code 403
# Status 403 for championship in 2023 - Attempt 3 - Error code 403
#
# championship and 2023 - Successfully scraped
#
# Scraping data for championship in 2024...
#
# championship and 2024 - Successfully scraped
#
# Team links for championship saved.
# Scraping data for laliga2 in 2011...
# Status 403 for laliga2 in 2011 - Attempt 1 - Error code 403
#
# laliga2 and 2011 - Successfully scraped
#
# Scraping data for laliga2 in 2012...
# Status 403 for laliga2 in 2012 - Attempt 1 - Error code 403
#
# laliga2 and 2012 - Successfully scraped
#
# Scraping data for laliga2 in 2013...
# Status 403 for laliga2 in 2013 - Attempt 1 - Error code 403
#
# laliga2 and 2013 - Successfully scraped
#
# Scraping data for laliga2 in 2014...
# Status 403 for laliga2 in 2014 - Attempt 1 - Error code 403
# Status 403 for laliga2 in 2014 - Attempt 2 - Error code 403
# Status 403 for laliga2 in 2014 - Attempt 3 - Error code 403
# Status 403 for laliga2 in 2014 - Attempt 4 - Error code 403
#
# laliga2 and 2014 - Successfully scraped
#
# Scraping data for laliga2 in 2015...
# Status 403 for laliga2 in 2015 - Attempt 1 - Error code 403
# Status 403 for laliga2 in 2015 - Attempt 2 - Error code 403
# Status 403 for laliga2 in 2015 - Attempt 3 - Error code 403
# Status 403 for laliga2 in 2015 - Attempt 4 - Error code 403
# Status 403 for laliga2 in 2015 - Attempt 5 - Error code 403
# Failed to retrieve data for laliga2 in 2015
# Scraping data for laliga2 in 2016...
#
# laliga2 and 2016 - Successfully scraped
#
# Scraping data for laliga2 in 2017...
# Status 403 for laliga2 in 2017 - Attempt 1 - Error code 403
#
# laliga2 and 2017 - Successfully scraped
#
# Scraping data for laliga2 in 2018...
#
# laliga2 and 2018 - Successfully scraped
#
# Scraping data for laliga2 in 2019...
# Status 403 for laliga2 in 2019 - Attempt 1 - Error code 403
# Status 403 for laliga2 in 2019 - Attempt 2 - Error code 403
#
# laliga2 and 2019 - Successfully scraped
#
# Scraping data for laliga2 in 2020...
#
# laliga2 and 2020 - Successfully scraped
#
# Scraping data for laliga2 in 2021...
# Status 403 for laliga2 in 2021 - Attempt 1 - Error code 403
#
# laliga2 and 2021 - Successfully scraped
#
# Scraping data for laliga2 in 2022...
# Status 403 for laliga2 in 2022 - Attempt 1 - Error code 403
#
# laliga2 and 2022 - Successfully scraped
#
# Scraping data for laliga2 in 2023...
# Status 403 for laliga2 in 2023 - Attempt 1 - Error code 403
# Status 403 for laliga2 in 2023 - Attempt 2 - Error code 403
#
# laliga2 and 2023 - Successfully scraped
#
# Scraping data for laliga2 in 2024...
#
# laliga2 and 2024 - Successfully scraped
#
# Team links for laliga2 saved.
# Scraping data for serie-b in 2011...
# Status 403 for serie-b in 2011 - Attempt 1 - Error code 403
#
# serie-b and 2011 - Successfully scraped
#
# Scraping data for serie-b in 2012...
# Status 403 for serie-b in 2012 - Attempt 1 - Error code 403
# Status 403 for serie-b in 2012 - Attempt 2 - Error code 403
# Status 403 for serie-b in 2012 - Attempt 3 - Error code 403
# Status 403 for serie-b in 2012 - Attempt 4 - Error code 403
#
# serie-b and 2012 - Successfully scraped
#
# Scraping data for serie-b in 2013...
#
# serie-b and 2013 - Successfully scraped
#
# Scraping data for serie-b in 2014...
#
# serie-b and 2014 - Successfully scraped
#
# Scraping data for serie-b in 2015...
#
# serie-b and 2015 - Successfully scraped
#
# Scraping data for serie-b in 2016...
#
# serie-b and 2016 - Successfully scraped
#
# Scraping data for serie-b in 2017...
#
# serie-b and 2017 - Successfully scraped
#
# Scraping data for serie-b in 2018...
#
# serie-b and 2018 - Successfully scraped
#
# Scraping data for serie-b in 2019...
#
# serie-b and 2019 - Successfully scraped
#
# Scraping data for serie-b in 2020...
#
# serie-b and 2020 - Successfully scraped
#
# Scraping data for serie-b in 2021...
#
# serie-b and 2021 - Successfully scraped
#
# Scraping data for serie-b in 2022...
#
# serie-b and 2022 - Successfully scraped
#
# Scraping data for serie-b in 2023...
#
# serie-b and 2023 - Successfully scraped
#
# Scraping data for serie-b in 2024...
#
# serie-b and 2024 - Successfully scraped
#
# Team links for serie-b saved.
# Scraping data for 2-bundesliga in 2011...
#
# 2-bundesliga and 2011 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2012...
#
# 2-bundesliga and 2012 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2013...
# Status 403 for 2-bundesliga in 2013 - Attempt 1 - Error code 403
#
# 2-bundesliga and 2013 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2014...
#
# 2-bundesliga and 2014 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2015...
# Status 403 for 2-bundesliga in 2015 - Attempt 1 - Error code 403
# Status 403 for 2-bundesliga in 2015 - Attempt 2 - Error code 403
# Status 403 for 2-bundesliga in 2015 - Attempt 3 - Error code 403
#
# 2-bundesliga and 2015 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2016...
# Status 403 for 2-bundesliga in 2016 - Attempt 1 - Error code 403
# Status 403 for 2-bundesliga in 2016 - Attempt 2 - Error code 403
# Status 403 for 2-bundesliga in 2016 - Attempt 3 - Error code 403
#
# 2-bundesliga and 2016 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2017...
# Status 403 for 2-bundesliga in 2017 - Attempt 1 - Error code 403
# Status 403 for 2-bundesliga in 2017 - Attempt 2 - Error code 403
# Status 403 for 2-bundesliga in 2017 - Attempt 3 - Error code 403
# Status 403 for 2-bundesliga in 2017 - Attempt 4 - Error code 403
#
# 2-bundesliga and 2017 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2018...
# Status 403 for 2-bundesliga in 2018 - Attempt 1 - Error code 403
#
# 2-bundesliga and 2018 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2019...
# Status 403 for 2-bundesliga in 2019 - Attempt 1 - Error code 403
#
# 2-bundesliga and 2019 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2020...
#
# 2-bundesliga and 2020 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2021...
#
# 2-bundesliga and 2021 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2022...
# Status 403 for 2-bundesliga in 2022 - Attempt 1 - Error code 403
# Status 403 for 2-bundesliga in 2022 - Attempt 2 - Error code 403
#
# 2-bundesliga and 2022 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2023...
#
# 2-bundesliga and 2023 - Successfully scraped
#
# Scraping data for 2-bundesliga in 2024...
#
# 2-bundesliga and 2024 - Successfully scraped
#
# Team links for 2-bundesliga saved.
# Scraping data for ligue-2 in 2011...
#
# ligue-2 and 2011 - Successfully scraped
#
# Scraping data for ligue-2 in 2012...
#
# ligue-2 and 2012 - Successfully scraped
#
# Scraping data for ligue-2 in 2013...
#
# ligue-2 and 2013 - Successfully scraped
#
# Scraping data for ligue-2 in 2014...
#
# ligue-2 and 2014 - Successfully scraped
#
# Scraping data for ligue-2 in 2015...
#
# ligue-2 and 2015 - Successfully scraped
#
# Scraping data for ligue-2 in 2016...
#
# ligue-2 and 2016 - Successfully scraped
#
# Scraping data for ligue-2 in 2017...
#
# ligue-2 and 2017 - Successfully scraped
#
# Scraping data for ligue-2 in 2018...
#
# ligue-2 and 2018 - Successfully scraped
#
# Scraping data for ligue-2 in 2019...
# Status 403 for ligue-2 in 2019 - Attempt 1 - Error code 403
# Status 403 for ligue-2 in 2019 - Attempt 2 - Error code 403
#
# ligue-2 and 2019 - Successfully scraped
#
# Scraping data for ligue-2 in 2020...
#
# ligue-2 and 2020 - Successfully scraped
#
# Scraping data for ligue-2 in 2021...
# Status 403 for ligue-2 in 2021 - Attempt 1 - Error code 403
# Status 403 for ligue-2 in 2021 - Attempt 2 - Error code 403
# Status 403 for ligue-2 in 2021 - Attempt 3 - Error code 403
#
# ligue-2 and 2021 - Successfully scraped
#
# Scraping data for ligue-2 in 2022...
# Status 403 for ligue-2 in 2022 - Attempt 1 - Error code 403
# Status 403 for ligue-2 in 2022 - Attempt 2 - Error code 403
#
# ligue-2 and 2022 - Successfully scraped
#
# Scraping data for ligue-2 in 2023...
# Status 403 for ligue-2 in 2023 - Attempt 1 - Error code 403
#
# ligue-2 and 2023 - Successfully scraped
#
# Scraping data for ligue-2 in 2024...
# Status 403 for ligue-2 in 2024 - Attempt 1 - Error code 403
#
# ligue-2 and 2024 - Successfully scraped
#
# Team links for ligue-2 saved.
